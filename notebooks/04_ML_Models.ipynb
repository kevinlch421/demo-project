# %% [markdown]
# # **Comparison of Machine Learning Prediction Models**
#
# Reference:
# - https://www.kaggle.com/code/sudhirnl7/linear-regression-tutorial
# - https://github.com/ashishpatel26/Amazing-Feature-Engineering/blob/master/A%20Short%20Guide%20for%20Feature%20Engineering%20and%20Feature%20Selection.md
# - https://github.com/Avinash793/regression-analysis-examples/blob/master/Exchange%20Rate%20Regimes%20Using%20%20Multiple%20Linear%20Regression%20Model.ipynb
# - https://github.com/stefan-jansen/machine-learning-for-trading/blob/main/07_linear_models/03_preparing_the_model_data.ipynb
# - https://github.com/leihao1/Comparison-of-Machine-Learning-Prediction-Models/blob/master/regression/regression.ipynb
# - https://github.com/VenkyAdi/Customer-Purchase-Behavior-Analysis-using-Descriptive-Statistics/blob/main/Applied_Statistics_Project.ipynb
#
#
# ![image.png](attachment:fd1e85e6-e787-49e0-abe6-c676567f90ee.png)

# %% [markdown]
# # Load Libary

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import TimeSeriesSplit
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
from torch.utils.data import DataLoader, TensorDataset
from scipy.stats import norm
import matplotlib.pyplot as plt
import itertools
import random

# %% [markdown]
# # Load Data

# %%
# Load Data
def load_stock_data(file_path, start_date, end_date):
    """Load stock data from SQLite database using StockFeaturePipeline."""
    pipeline = StockFeaturePipeline(file_path)
    data = pipeline.run_pipeline(start_date, end_date)
    return data

# %%
file_path = '/Users/kevinleungch421/Documents/GitHub/Database/DataBase/stock_price.sqlite'
raw_data = load_stock_data(file_path, '2017-01-01', '2021-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Final DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 48 entries, 2017-01-31 to 2020-12-31
# Freq: M
# Columns: 189 entries, open to Future_Log_Returns
# dtypes: float64(185), int64(2), object(1), period[M](1)
# memory usage: 71.2+ KB
# None

# %% [markdown]
# # Handle Missing Values

# %%
# Handle Missing Values
def handle_missing_values(df):
    """Remove rows with missing target and fill NaNs in numerical columns with means."""
    df = df.dropna(subset=['Future_Log_Returns'])  # Drop rows where target is NaN
    numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.drop('Future_Log_Returns', errors='ignore')
    for col in numerical_cols:
        df[col] = df[col].fillna(df[col].mean())
    return df

# %%
# Run
clean_data = handle_missing_values(raw_data)

# %%
# B4
print("Missing Values before Cleaning:")
print(raw_data.isnull().sum().sort_values(ascending=False))

# AF
print("Missing Values After Cleaning:")
print(clean_data.isnull().sum().sort_values(ascending=False))
# Out:
# Missing Values before Cleaning:
# Future_Log_Returns    1
# ^VXN_lag1             0
# ^TNX_lag63            0
# DX-Y.NYB_lag1         0
# DX-Y.NYB_lag10        0
#                      ..
# Typical_Price         0
# VWAP_20               0
# Unemployment_error    0
# CPI_error             0
# ^VIX_lag1             0
# Length: 189, dtype: int64
# Missing Values After Cleaning:
# open                  0
# ^VXN_lag1             0
# ^TNX_lag63            0
# DX-Y.NYB_lag1         0
# DX-Y.NYB_lag10        0
#                      ..
# Typical_Price         0
# VWAP_20               0
# Unemployment_error    0
# CPI_error             0
# Future_Log_Returns    0
# Length: 189, dtype: int64

# %% [markdown]
# # Detect and Handle Outliers

# %%
# Detect and Handle Outliers
def z_score_mark_outliers(df, threshold=3, handle_outliers=True):
    """Detect and cap outliers using z-scores."""
    df = df.copy()
    numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
    
    if not numerical_cols.size:
        print("No numerical columns found.")
        return df
    
    total_outliers = 0
    for col in numerical_cols:
        mean = df[col].mean()
        std = df[col].std()
        if std == 0:
            continue
        z_scores = np.abs((df[col] - mean) / std)
        col_outliers = z_scores > threshold
        total_outliers += col_outliers.sum()
        if handle_outliers:
            lower_bound = mean - threshold * std
            upper_bound = mean + threshold * std
            df[col] = df[col].clip(lower=lower_bound, upper=upper_bound)
    
    prob = 100 * 2 * norm.sf(threshold)
    print(f"z-score threshold {threshold}: {prob:.2f}% probability, {total_outliers} outliers handled.")
    return df

# %%
# Run
outlier_data = z_score_mark_outliers(clean_data)
# Out:
# z-score threshold 3: 0.27% probability, 65 outliers handled.

# %%
# Box Plot compair 
def box_plot(df, column):
    sns.boxplot(df[column])
    plt.title(f'Box Plot of {column}')
    plt.show()

column = 'Retail_Sales_Predicted'

# B4
box_plot(clean_data, column)

# AF
box_plot(outlier_data, column)

# %% [markdown]
# # Apply Log Transformation

# %%
def log_transform_df(df):
    """Apply log transformation to numerical columns, handling non-positive values."""
    df = df.copy()
    numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
    
    if not numerical_cols.size:
        print("No numerical columns found.")
        return df
    
    for col in numerical_cols:
        min_value = df[col].min()
        constant = abs(min_value) + 1 if min_value <= 0 else 1
        df[col] = np.log(df[col] + constant)
    return df

# %%
transformed_data = log_transform_df(outlier_data)

# %%
def bar_plot(df, column):
    plt.hist(df[column])
    plt.title(f'distribution on {column}')
    plt.show()

column = 'Retail_Sales_Predicted'

# B4
bar_plot(outlier_data, column)

# AF
bar_plot(transformed_data, column)

# %% [markdown]
# # Scale Data

# %%
# Scale Data
def min_max_scaler_all_numerical(df, feature_range=(0, 1)):
    """Scale all numerical columns using Min-Max scaling."""
    df = df.copy()
    numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
    
    if not numerical_cols.size:
        print("No numerical columns found.")
        return df
    
    for col in numerical_cols:
        if df[col].isna().all() or df[col].nunique() <= 1:
            print(f"Skipping {col}: NaN or constant.")
            continue
        col_min, col_max = df[col].min(), df[col].max()
        if col_max == col_min:
            continue
        df[col] = (df[col] - col_min) / (col_max - col_min) * (feature_range[1] - feature_range[0]) + feature_range[0]
    return df

# %%
# Run
scaled_df = min_max_scaler_all_numerical(transformed_data)

# %%
column = 'Retail_Sales_Predicted'

# B4
bar_plot(transformed_data, column)

# AF
bar_plot(scaled_df, column)

# %% [markdown]
# # Visualization

# %%
numeric_df = scaled_df.select_dtypes(include=['int64', 'float64'])

# Compute correlation matrix
plt.figure(figsize=(18, 18))
cor1 = numeric_df.corr()
sns.heatmap(cor1, annot=True, cmap="Blues", annot_kws={"size": 8})
plt.title("Correlation Heatmap of Numeric Features")
plt.show()

# %%
# Select numeric columns
numeric_df = scaled_df.select_dtypes(include=['int64', 'float64'])

# Get numerical columns
numerical_cols = numeric_df.columns

if not numerical_cols.size:
    print("No numerical columns found in the DataFrame.")
else:
    # Set grid parameters
    cols_per_figure = 5
    plots_per_figure = 15  # Number of plots per figure (adjustable)
    rows_per_figure = (plots_per_figure + cols_per_figure - 1) // cols_per_figure  # Ceiling division
    
    # Calculate number of figures needed
    num_figures = (len(numerical_cols) + plots_per_figure - 1) // plots_per_figure
    
    for fig_num in range(num_figures):
        start_idx = fig_num * plots_per_figure
        end_idx = min((fig_num + 1) * plots_per_figure, len(numerical_cols))
        current_cols = numerical_cols[start_idx:end_idx]
        
        if not current_cols.size:
            break
        
        # Create a new figure with dynamic rows
        fig, axes = plt.subplots(rows_per_figure, cols_per_figure, figsize=(15, 3 * rows_per_figure))
        axes = axes.flatten()  # Flatten for easier indexing
        
        for i, col in enumerate(current_cols):
            ax = axes[i]
            # Generate Q-Q plot
            probplot(numeric_df[col].dropna(), dist="norm", plot=ax)
            ax.set_title(col, fontsize=8)
            ax.set_xlabel('Theoretical Quantiles', fontsize=6)
            ax.set_ylabel('Sample Quantiles', fontsize=6)
            ax.grid(True, alpha=0.3)
            ax.tick_params(axis='both', labelsize=6)
        
        # Hide unused subplots
        for j in range(i + 1, len(axes)):
            axes[j].set_visible(False)
        
        # Adjust layout and display
        plt.tight_layout()
        plt.show()

# %% [markdown]
# # Train-Test Split

# %%
# Prepare Sequences
def prepare_sequences(df, seq_len=10, test_size=0.2):
    """Convert DataFrame into sequences for time series modeling."""
    for col in df.columns:
        if pd.api.types.is_period_dtype(df[col]):
            df[col] = df[col].apply(lambda x: x.to_timestamp().toordinal() if pd.notnull(x) else np.nan)
    
    numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns.drop('Future_Log_Returns', errors='ignore')
    for col in numerical_cols:
        q1, q3 = df[col].quantile([0.25, 0.75])
        iqr = q3 - q1
        df[col] = df[col].clip(q1 - 1.5 * iqr, q3 + 1.5 * iqr)
    df[numerical_cols] = df[numerical_cols].fillna(method='ffill').fillna(0)
    
    X_seq, y_seq = [], []
    for i in range(seq_len, len(df)):
        X_seq.append(df.iloc[i-seq_len:i][numerical_cols].values)
        y_seq.append(df.iloc[i]['Future_Log_Returns'])
    X_seq, y_seq = np.array(X_seq, dtype=float), np.array(y_seq, dtype=float)
    
    if not np.all(np.isfinite(X_seq)) or not np.all(np.isfinite(y_seq)):
        raise ValueError("Data contains NaN or infinite values")
    
    train_size = int((1 - test_size) * len(X_seq))
    X_train, y_train = X_seq[:train_size], y_seq[:train_size]
    X_test, y_test = X_seq[train_size:], y_seq[train_size:]
    return X_train, y_train, X_test, y_test, numerical_cols

# %%
# Run
X_train, y_train, X_test, y_test, numerical_cols = prepare_sequences(scaled_df)

# %%
# Info
print('X_train : ') 
print(X_train.shape) 
print('') 
print('X_test : ') 
print(X_test.shape) 
print('') 
print('y_train : ') 
print(y_train.shape) 
print('') 
print('y_test : ') 
print(y_test.shape)
# Out:
# X_train :
# (29, 10, 187)
#
# X_test :
# (8, 10, 187)
#
# y_train :
# (29,)
#
# y_test :
# (8,)

# %% [markdown]
# # Select Features

# %%
# Modified Select Features function that returns RFECV model
def select_features(X_train, y_train, X_test, numerical_cols, n_features=50):
    """Select top features using RFECV."""
    X_train_last = X_train[:, -1, :]
    estimator = RandomForestRegressor(n_estimators=100, random_state=42)
    rfecv = RFECV(estimator, step=1, cv=TimeSeriesSplit(n_splits=5), scoring='neg_mean_squared_error')
    rfecv.fit(X_train_last, y_train)
    
    selected_mask = rfecv.support_
    selected_features = numerical_cols[selected_mask]
    importances = rfecv.estimator_.feature_importances_
    feature_df = pd.DataFrame({'feature': selected_features, 'importance': importances}).sort_values('importance', ascending=False)
    top_features = feature_df.head(n_features)['feature'].tolist()
    selected_indices = [list(numerical_cols).index(f) for f in top_features]
    
    print(f"Selected {len(selected_indices)} features:")
    print(feature_df.head(n_features))
    
    # Return the RFECV model for plotting
    return X_train[:, :, selected_indices], X_test[:, :, selected_indices], selected_indices, rfecv

# %%
# Run feature selection and get RFECV model
X_train_sel, X_test_sel, sel_indices, rfecv = select_features(X_train, y_train, X_test, numerical_cols)
# Out:
# Selected 50 features:
#                              feature  importance
# 72                        ^VXN_lag10    0.095380
# 76                   000001.SS_lag42    0.079458
# 36                     Nonfarm_error    0.061208
# 82                       ^N225_lag42    0.044207
# 4            Nonfarm_Payrolls_Actual    0.035530
# 48                        ^VIX_lag10    0.028841
# 90                        ^MXX_lag10    0.028659
# 46                      volume_lag42    0.023146
# 63                         VXUS_lag1    0.022174
# 80                        ^N225_lag1    0.022036
# 25                              MACD    0.021669
# 53                        BZ=F_lag42    0.019653
# 28                            RSI_14    0.018533
# 89                         ^MXX_lag1    0.018483
# 21                             ^FTSE    0.016503
# 52                        BZ=F_lag10    0.015021
# 98                       ^FCHI_lag63    0.014634
# 109                      ^BVSP_lag42    0.014062
# 11            Personal_Income_Actual    0.013693
# 54                        BZ=F_lag63    0.013053
# 44                       volume_lag1    0.012638
# 34                               OBV    0.012534
# 49                        ^VIX_lag42    0.011772
# 71                         ^VXN_lag1    0.011406
# 45                      volume_lag10    0.011378
# 85                      ^GDAXI_lag63    0.011246
# 12         Personal_Income_Predicted    0.010465
# 1                             volume    0.009606
# 8    Industrial_Production_Predicted    0.009176
# 19                            ^GDAXI    0.008733
# 20                              ^MXX    0.008445
# 51                         BZ=F_lag1    0.008433
# 47                      volume_lag63    0.008353
# 83                      ^GDAXI_lag10    0.008042
# 102                       ^HSI_lag63    0.007805
# 81                       ^N225_lag10    0.007721
# 87                     ^GSPTSE_lag42    0.007543
# 59                     BTC-USD_lag63    0.007507
# 101                       ^HSI_lag42    0.007071
# 62                         IXN_lag63    0.006612
# 96                        ^FCHI_lag1    0.006488
# 73                        ^VXN_lag42    0.006411
# 56                      BTC-USD_lag1    0.006373
# 69                       ^GSPC_lag10    0.006241
# 6             Retail_Sales_Predicted    0.005855
# 24                            EMA_50    0.005542
# 95                       ^FTSE_lag63    0.005542
# 75                    000001.SS_lag1    0.005521
# 70                       ^GSPC_lag63    0.005114
# 43                       close_lag63    0.005021

# %%
# plotting 
def plot_features_vs_cvscore(rfecv_model):
    n_features = len(rfecv_model.cv_results_["mean_test_score"])
    plt.figure(figsize=(15, 10))
    plt.xlabel("Number of features selected")
    plt.ylabel("Negative Mean Squared Error")
    plt.plot(range(1, n_features + 1), rfecv_model.cv_results_["mean_test_score"])
    plt.fill_between(range(1, n_features + 1), 
                     rfecv_model.cv_results_["mean_test_score"] - rfecv_model.cv_results_["std_test_score"], 
                     rfecv_model.cv_results_["mean_test_score"] + rfecv_model.cv_results_["std_test_score"], 
                     alpha=0.3, 
                     color="lightblue")
    plt.title("Feature Selection Performance (Higher is Better)")
    plt.show()

# Plot feature selection results
plot_features_vs_cvscore(rfecv)

# %% [markdown]
# # Convert to tensors
# y_test: Unlike the training data, which is used to train the model in batches via a DataLoader, y_test is used solely for evaluation.

# %%
# Convert to tensors
X_train_tensor = torch.tensor(X_train_sel, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
X_test_tensor = torch.tensor(X_test_sel, dtype=torch.float32)
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=False)

# Data preparation for linear regression
X_train_lr = X_train_sel[:, -1, :]
X_test_lr = X_test_sel[:, -1, :]
X_train_lr_tensor = torch.tensor(X_train_lr, dtype=torch.float32)
X_test_lr_tensor = torch.tensor(X_test_lr, dtype=torch.float32)
train_dataset_lr = TensorDataset(X_train_lr_tensor, y_train_tensor)
train_loader_lr = DataLoader(train_dataset_lr, batch_size=64, shuffle=False)

# %%
# Print tensor shapes
print(f"X_train_tensor shape: {X_train_tensor.shape}")
print(f"y_train_tensor shape: {y_train_tensor.shape}")
print(f"X_test_tensor shape: {X_test_tensor.shape}")
print(f"y_train_tensor shape: {y_train_tensor.shape}")
# Out:
# X_train_tensor shape: torch.Size([29, 10, 50])
# y_train_tensor shape: torch.Size([29, 1])
# X_test_tensor shape: torch.Size([8, 10, 50])
# y_train_tensor shape: torch.Size([29, 1])

# %%
# Display a sample
print("Sample of X_train_tensor (first sequence):")
print(X_train_tensor[0])
print("Sample of y_train_tensor (first target):")
print(y_train_tensor[0])
# Out:
# Sample of X_train_tensor (first sequence):
# tensor([[0.1649, 0.5821, 0.8542, 0.5123, 0.9762, 0.1107, 0.7384, 0.2646, 0.0850,
#          0.0488, 0.7956, 0.7178, 0.8345, 0.7922, 0.7337, 0.6505, 0.5762, 0.5235,
#          0.4708, 0.7374, 0.3323, 0.8810, 0.4186, 0.1364, 0.0513, 0.6960, 0.9796,
#          0.2782, 0.6503, 0.5006, 0.7820, 0.6929, 0.5663, 0.5300, 0.4245, 0.2515,
#          0.6131, 0.7116, 0.4303, 0.4678, 0.2842, 0.4517, 0.1047, 0.0000, 0.5486,
#          0.0000, 0.7256, 0.7048, 0.4610, 0.0000],
#         [0.0918, 0.5821, 0.8619, 0.5123, 0.9767, 0.0697, 0.8230, 0.2056, 0.1408,
#          0.0071, 0.8117, 0.7178, 0.9735, 0.8057, 0.8033, 0.6526, 0.5762, 0.5235,
#          0.4810, 0.7374, 0.0000, 0.9136, 0.4186, 0.1112, 0.1900, 0.6960, 0.9592,
#          0.2193, 0.6021, 0.5908, 0.7742, 0.7027, 0.1973, 0.5841, 0.4245, 0.3358,
#          0.6131, 0.7116, 0.4303, 0.4678, 0.3245, 0.4517, 0.1047, 0.0574, 0.5101,
#          0.0367, 0.7256, 0.7697, 0.4610, 0.0153],
#         [0.0000, 0.6884, 0.8602, 0.0000, 0.9767, 0.0807, 0.8692, 0.2766, 0.2250,
#          0.0000, 0.7741, 0.6774, 0.8505, 0.8837, 0.8281, 0.5848, 0.5762, 0.0497,
#          0.4810, 0.7374, 0.1326, 0.9239, 0.1486, 0.0245, 0.2431, 0.6960, 0.9796,
#          0.2944, 0.6118, 0.7305, 0.8639, 0.6601, 0.2186, 0.6563, 0.4245, 0.3438,
#          0.5019, 0.7116, 0.0226, 0.4678, 0.4822, 0.1478, 0.1047, 0.1037, 0.5101,
#          0.0709, 0.7256, 0.7526, 0.4610, 0.0265],
#         [0.2484, 0.7621, 0.8471, 0.0168, 0.9759, 0.2867, 0.8869, 0.2181, 0.2762,
#          0.0302, 0.7864, 0.6759, 0.9868, 0.9128, 0.7783, 0.6577, 0.3122, 0.0986,
#          0.4606, 0.6883, 0.1339, 0.9212, 0.1959, 0.0000, 0.2983, 0.5711, 0.9592,
#          0.3524, 0.6407, 0.7662, 0.9014, 0.6373, 0.2633, 0.6594, 0.0000, 0.1996,
#          0.5052, 0.1046, 0.0684, 0.0000, 0.5948, 0.1134, 0.1227, 0.0580, 0.4972,
#          0.0907, 0.7600, 0.6982, 0.0000, 0.0793],
#         [0.0554, 0.7342, 0.8593, 0.0047, 0.9766, 0.0471, 0.9113, 0.2051, 0.3625,
#          0.0975, 0.8067, 0.6388, 0.9337, 0.9046, 0.9089, 0.5828, 0.3923, 0.0644,
#          0.4810, 0.6894, 0.2380, 0.9432, 0.1246, 0.0967, 0.2560, 0.6466, 0.9796,
#          0.5113, 0.6310, 0.8160, 0.8768, 0.6434, 0.4546, 0.8094, 0.0512, 0.3943,
#          0.5503, 0.1046, 0.1346, 0.0497, 0.6156, 0.0000, 0.2942, 0.1242, 0.5422,
#          0.1303, 0.8476, 0.6581, 0.1023, 0.1259],
#         [0.2637, 0.6744, 0.8513, 0.0866, 0.9761, 0.0322, 0.8998, 0.2599, 0.3736,
#          0.1810, 0.7323, 0.6019, 0.4517, 0.9006, 0.8238, 0.5008, 0.4964, 0.1001,
#          0.4810, 0.6496, 0.9063, 0.9164, 0.0707, 0.3317, 0.6569, 0.7185, 0.9592,
#          0.8181, 0.6118, 0.7340, 0.9319, 0.5739, 0.3613, 0.7986, 0.0918, 0.3972,
#          0.5605, 0.1046, 0.1804, 0.0709, 0.5227, 0.0794, 0.3471, 0.1536, 0.5101,
#          0.1533, 0.8214, 0.7320, 0.0692, 0.1357],
#         [0.1917, 0.6501, 0.8610, 0.1298, 0.9766, 0.0000, 1.0000, 0.5084, 0.4713,
#          0.1412, 0.7918, 0.5996, 0.7117, 1.0000, 0.8484, 0.5216, 0.5869, 0.0000,
#          0.4401, 0.6300, 0.5220, 0.9275, 0.0600, 0.2342, 0.3326, 0.7545, 0.9796,
#          0.5191, 0.6214, 0.6743, 0.9901, 0.6535, 0.4406, 0.7634, 0.1518, 0.4191,
#          0.4928, 0.1529, 0.2891, 0.1110, 0.5084, 0.0789, 0.3817, 0.1768, 0.5101,
#          0.1717, 0.7687, 0.7923, 0.0947, 0.1737],
#         [0.3456, 0.7214, 0.8593, 0.2139, 0.9765, 0.2711, 0.9842, 0.5029, 0.4702,
#          0.0706, 0.7553, 0.5900, 0.8232, 0.9990, 0.8725, 0.5713, 0.6334, 0.0146,
#          0.4810, 0.6059, 0.4667, 0.9255, 0.1069, 0.2007, 0.8484, 0.8632, 0.9592,
#          0.5731, 0.6214, 0.6561, 1.0000, 0.6285, 0.5844, 0.6802, 0.3023, 0.3669,
#          0.4501, 0.3496, 0.3027, 0.1690, 0.4612, 0.3382, 0.5479, 0.1508, 0.5294,
#          0.1853, 0.9185, 0.8918, 0.1445, 0.2211],
#         [0.1016, 0.8067, 0.8539, 0.1995, 0.9762, 0.0203, 0.9335, 0.2991, 0.5305,
#          0.2026, 0.7477, 0.6340, 0.6961, 0.9474, 0.8487, 0.6531, 0.4952, 0.0951,
#          0.4606, 0.5737, 0.3165, 0.9248, 0.0406, 0.1945, 0.6391, 0.7220, 0.9388,
#          0.6208, 0.6021, 0.8752, 0.9567, 0.7231, 0.8027, 0.7488, 0.2843, 0.3930,
#          0.4552, 0.3485, 0.4897, 0.1345, 0.6082, 0.1737, 0.5173, 0.2130, 0.5101,
#          0.1988, 0.8169, 0.8704, 0.1292, 0.1800],
#         [0.1875, 0.8653, 0.8418, 0.1289, 0.9750, 0.0283, 0.9439, 0.5697, 0.5922,
#          0.4417, 0.7925, 0.6304, 0.9417, 0.8832, 0.8980, 0.6909, 0.4867, 0.1966,
#          0.4810, 0.6426, 0.4402, 0.9429, 0.0707, 0.1976, 0.0000, 0.6802, 0.9796,
#          0.4133, 0.6214, 0.9836, 0.8683, 0.7693, 0.6252, 0.8491, 0.4849, 0.5658,
#          0.4577, 0.3796, 0.5336, 0.1940, 0.7270, 0.1497, 0.6487, 0.2640, 0.5823,
#          0.2220, 0.8600, 0.9153, 0.1816, 0.2277]])
# Sample of y_train_tensor (first target):
# tensor([0.4452])

# %% [markdown]
# # Define Models For Comparison

# %%
class LinearRegressionModel(nn.Module):
    def __init__(self, input_size):
        super(LinearRegressionModel, self).__init__()
        self.linear = nn.Linear(input_size, 1)
    def forward(self, x):
        return self.linear(x)

# %%
class VanillaLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(VanillaLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# %%
class BidirectionalLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(BidirectionalLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_size * 2, output_size)
    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# %%
class CNNLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(CNNLSTM, self).__init__()
        self.conv = nn.Conv1d(input_size, hidden_size, kernel_size=3, padding=1)
        self.lstm = nn.LSTM(hidden_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    def forward(self, x):
        x = x.transpose(1, 2)  # [batch, features, seq_len]
        x = self.conv(x)       # [batch, hidden_size, seq_len]
        x = x.transpose(1, 2)  # [batch, seq_len, hidden_size]
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# # Training Function
#
# This function trains a PyTorch model using a training data loader, implements early stopping based on validation loss (computed on the test set), and returns the trained model.
#
# Loss Function and Optimizer:
# - nn.MSELoss() is appropriate for regression tasks, matching the context of predicting continuous values.
# - optim.Adam with a learning rate of 0.0005 and weight_decay=1e-5 (for regularization) is a standard choice.

# %%
# Training function without CV
def train_model(model, train_loader, X_test, y_test, epochs=50, patience=5, lr=0.0005):
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)
    best_loss = float('inf')
    trigger = 0
    
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        avg_loss = running_loss / len(train_loader)
        
        model.eval()
        with torch.no_grad():
            y_pred_test = model(X_test).numpy().flatten()
            test_loss = mean_squared_error(y_test, y_pred_test)
            if test_loss < best_loss:
                best_loss = test_loss
                trigger = 0
            else:
                trigger += 1
                if trigger >= patience:
                    break
    return model

# Training function with Cross-Validation
def train_model_cv(model, X_train, y_train, X_test, y_test, epochs=50, patience=5, lr=0.0005, n_splits=5):
    tscv = TimeSeriesSplit(n_splits=n_splits)
    cv_mse = []
    
    for fold, (train_idx, val_idx) in enumerate(tscv.split(X_train)):
        print(f"Fold {fold+1}/{n_splits}")
        
        X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
        X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]
        
        train_dataset_fold = TensorDataset(torch.tensor(X_train_fold, dtype=torch.float32), 
                                           torch.tensor(y_train_fold, dtype=torch.float32).view(-1, 1))
        train_loader_fold = DataLoader(train_dataset_fold, batch_size=64, shuffle=False)
        
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)
        best_loss = float('inf')
        trigger = 0
        
        for epoch in range(epochs):
            model.train()
            running_loss = 0.0
            for X_batch, y_batch in train_loader_fold:
                optimizer.zero_grad()
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()
            avg_loss = running_loss / len(train_loader_fold)
            
            model.eval()
            with torch.no_grad():
                y_pred_val = model(torch.tensor(X_val_fold, dtype=torch.float32)).numpy().flatten()
                val_loss = mean_squared_error(y_val_fold, y_pred_val)
                if val_loss < best_loss:
                    best_loss = val_loss
                    trigger = 0
                else:
                    trigger += 1
                    if trigger >= patience:
                        print("Early stopping triggered")
                        break
        
        with torch.no_grad():
            y_pred_val = model(torch.tensor(X_val_fold, dtype=torch.float32)).numpy().flatten()
            mse_val = mean_squared_error(y_val_fold, y_pred_val)
            cv_mse.append(mse_val)
    
    # Train on full training set
    train_dataset_full = TensorDataset(torch.tensor(X_train, dtype=torch.float32), 
                                       torch.tensor(y_train, dtype=torch.float32).view(-1, 1))
    train_loader_full = DataLoader(train_dataset_full, batch_size=64, shuffle=False)
    model = train_model(model, train_loader_full, X_test, y_test, epochs=epochs, patience=patience, lr=lr)
    
    return model, np.mean(cv_mse)

# %% [markdown]
# # Evaluation Function
# This function evaluates the model on the test set, computes regression metrics, plots residuals, and returns the metrics.

# %%
# Evaluation function
def evaluate_model(model, X_test_tensor, y_test, model_name):
    model.eval()
    with torch.no_grad():
        y_pred = model(X_test_tensor).numpy().flatten()
    
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print(f"\n{model_name} Performance:")
    print(f"MSE: {mse:.4f}, RMSE: {rmse:.4f}, MAE: {mae:.4f}, R²: {r2:.4f}")
    
    residuals = y_test - y_pred
    plt.figure(figsize=(10, 6))
    plt.plot(residuals, label='Residuals')
    plt.title(f"{model_name} Residuals")
    plt.xlabel("Test Sample Index")
    plt.ylabel("Residual Value")
    plt.legend()
    plt.grid(True)
    plt.savefig(f"{model_name}_residuals.png")
    plt.close()
    
    return {'MSE': mse, 'RMSE': rmse, 'MAE': mae, 'R2': r2}

# %% [markdown]
# # 5-Folds cross validation

# %%
# Set seed for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED) 
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Model configurations with seed set before initialization
model_configs = [
    ('Linear Regression', (torch.manual_seed(SEED), LinearRegressionModel(input_size=len(sel_indices)))[1], train_loader_lr, X_test_lr_tensor),
    ('Vanilla LSTM', (torch.manual_seed(SEED), VanillaLSTM(len(sel_indices), 100, 2, 1))[1], train_loader, X_test_tensor),
    ('Bidirectional LSTM', (torch.manual_seed(SEED), BidirectionalLSTM(len(sel_indices), 100, 2, 1))[1], train_loader, X_test_tensor),
    ('CNN-LSTM', (torch.manual_seed(SEED), CNNLSTM(len(sel_indices), 100, 2, 1))[1], train_loader, X_test_tensor)
]

# Training and evaluation with CV
results = {}
for name, model, loader, X_test in model_configs:
    print(f"\nTraining {name} with Cross-Validation...")
    trained_model, cv_mse = train_model_cv(model, X_train_sel if 'LSTM' in name or 'CNN' in name else X_train_lr, 
                                           y_train, X_test, y_test)
    print(f"Cross-Validated MSE for {name}: {cv_mse:.4f}")
    results[name] = evaluate_model(trained_model, X_test, y_test, name)
# Out:
# Training Linear Regression with Cross-Validation...
# Fold 1/5
# Early stopping triggered
# Fold 2/5
# Early stopping triggered
# Fold 3/5
# Early stopping triggered
# Fold 4/5
# Early stopping triggered
# Fold 5/5
# Early stopping triggered
# Cross-Validated MSE for Linear Regression: 0.0883
#
# Linear Regression Performance:
# MSE: 0.0980, RMSE: 0.3131, MAE: 0.2850, R²: -0.6478
#
# Training Vanilla LSTM with Cross-Validation...
# Fold 1/5
# Early stopping triggered
# Fold 2/5
# Early stopping triggered
# Fold 3/5
# Early stopping triggered
# Fold 4/5
# Early stopping triggered
# Fold 5/5
# Early stopping triggered
# Cross-Validated MSE for Vanilla LSTM: 0.1155
#
# Vanilla LSTM Performance:
# MSE: 0.0775, RMSE: 0.2784, MAE: 0.2650, R²: -0.3026
#
# Training Bidirectional LSTM with Cross-Validation...
# Fold 1/5
# Early stopping triggered
# Fold 2/5
# Early stopping triggered
# Fold 3/5
# Early stopping triggered
# Fold 4/5
# Early stopping triggered
# Fold 5/5
# Early stopping triggered
# Cross-Validated MSE for Bidirectional LSTM: 0.0942
#
# Bidirectional LSTM Performance:
# MSE: 0.0666, RMSE: 0.2581, MAE: 0.2395, R²: -0.1197
#
# Training CNN-LSTM with Cross-Validation...
# Fold 1/5
# Early stopping triggered
# Fold 2/5
# Early stopping triggered
# Fold 3/5
# Early stopping triggered
# Fold 4/5
# Early stopping triggered
# Fold 5/5
# Early stopping triggered
# Cross-Validated MSE for CNN-LSTM: 0.1004
#
# CNN-LSTM Performance:
# MSE: 0.0709, RMSE: 0.2662, MAE: 0.2499, R²: -0.1914

# %%
print("\nModel Comparison Summary:")
for name, metrics in results.items():
    print(f"{name}: MSE={metrics['MSE']:.4f}, RMSE={metrics['RMSE']:.4f}, MAE={metrics['MAE']:.4f}, R²={metrics['R2']:.4f}")
# Out:
# Model Comparison Summary:
# Linear Regression: MSE=0.0980, RMSE=0.3131, MAE=0.2850, R²=-0.6478
# Vanilla LSTM: MSE=0.0775, RMSE=0.2784, MAE=0.2650, R²=-0.3026
# Bidirectional LSTM: MSE=0.0666, RMSE=0.2581, MAE=0.2395, R²=-0.1197
# CNN-LSTM: MSE=0.0709, RMSE=0.2662, MAE=0.2499, R²=-0.1914

# %% [markdown]
# # Plot validation loss

# %%
# Plot validation loss for each fold and model
n_folds = 5
fig, ax = plt.subplots(n_folds, figsize=(10, 20))
markers = {'Linear Regression': 'o', 'Vanilla LSTM': 'x', 'Bidirectional LSTM': 's', 'CNN-LSTM': '^'}

for i in range(n_folds):
    for name in val_loss_history.keys():
        val_losses = val_loss_history[name][i]
        sns.lineplot(
            x=np.arange(len(val_losses)), 
            y=val_losses, 
            ax=ax[i], 
            label=name, 
            marker=markers[name]
        )
    
    ax[i].set_title(f'Fold {i+1} Validation Loss')
    ax[i].set_xlabel('Epoch')
    ax[i].set_ylabel('Validation Loss (MSE)')
    ax[i].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Bidirectional LSTM is the best Model

# %%
pd.DataFrame(results)
# Out:
#       Linear Regression  Vanilla LSTM  Bidirectional LSTM  CNN-LSTM
# MSE            0.098020      0.077488            0.066609  0.070871
# RMSE           0.313082      0.278366            0.258087  0.266216
# MAE            0.285050      0.265049            0.239464  0.249905
# R2            -0.647756     -0.302592           -0.119714 -0.191362

# %% [markdown]
# # Model Tuning on Bidirectional LSTM

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import itertools

# BidirectionalLSTM class
class BidirectionalLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.0, activation=None):
        super(BidirectionalLSTM, self).__init__()
        self.lstm1 = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, bidirectional=True, dropout=dropout if num_layers > 1 else 0)
        self.lstm2 = nn.LSTM(hidden_size * 2, hidden_size, num_layers, batch_first=True, bidirectional=True, dropout=dropout if num_layers > 1 else 0)
        self.norm = nn.BatchNorm1d(hidden_size * 2)
        self.dropout = nn.Dropout(dropout)
        self.fc1 = nn.Linear(hidden_size * 2, hidden_size)
        self.fc2 = nn.Linear(hidden_size, output_size)
        self.activation = activation if activation is not None else nn.Identity()

    def forward(self, x):
        out, _ = self.lstm1(x)
        out, _ = self.lstm2(out)
        out = self.norm(out[:, -1, :])
        out = self.dropout(out)
        out = self.fc1(out)
        out = self.activation(out)
        out = self.fc2(out)
        return out

# Training function with checkpointing
def train_model(model, train_loader, X_val_tensor, y_val_tensor, epochs, patience, lr):
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    best_val_loss = float('inf')
    best_model_state = None
    patience_counter = 0

    for epoch in range(epochs):
        model.train()
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_outputs = model(X_val_tensor)
            val_loss = criterion(val_outputs, y_val_tensor)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_state = model.state_dict()
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"Early stopping at epoch {epoch+1}")
                break

    model.load_state_dict(best_model_state)
    return model

# Tuning function
def tune_bidirectional_lstm(X_train_tensor, y_train_tensor, X_test_tensor, y_test_tensor, sel_indices):
    learning_rates = [0.001, 0.0005, 0.0001]
    hidden_sizes = [50, 100, 150]
    num_layers_list = [1, 2, 3]
    dropout_rates = [0.2, 0.3, 0.4]
    batch_sizes = [32, 64, 128]
    activations = [None, nn.Tanh(), nn.ReLU(), nn.LeakyReLU(), nn.ELU()]

    best_mse = float('inf')
    best_params = {}
    best_model = None

    param_combinations = list(itertools.product(learning_rates, hidden_sizes, num_layers_list, dropout_rates, batch_sizes, activations))

    for lr, hidden_size, num_layers, dropout, batch_size, activation in param_combinations:
        print(f"\nTesting: lr={lr}, hidden={hidden_size}, layers={num_layers}, dropout={dropout}, batch={batch_size}, activation={activation}")
        train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

        model = BidirectionalLSTM(input_size=len(sel_indices), hidden_size=hidden_size, num_layers=num_layers, output_size=1, dropout=dropout, activation=activation)
        trained_model = train_model(model, train_loader, X_test_tensor, y_test_tensor, epochs=50, patience=5, lr=lr)
        metrics = evaluate_model(trained_model, X_test_tensor, y_test_tensor, f"BiLSTM (lr={lr}, hidden={hidden_size}, activation={activation})")

        if metrics['MSE'] < best_mse:
            best_mse = metrics['MSE']
            best_params = {
                'lr': lr,
                'hidden_size': hidden_size,
                'num_layers': num_layers,
                'dropout': dropout,
                'batch_size': batch_size,
                'activation': activation
            }
            best_model = trained_model
            

    print("\nBest Hyperparameters:", best_params)
    print(f"Best MSE: {best_mse:.4f}")
    return best_model, best_params

# Evaluation function
def evaluate_model(model, X_test_tensor, y_test_tensor, name):
    model.eval()
    with torch.no_grad():
        predictions = model(X_test_tensor)
        mse = nn.MSELoss()(predictions, y_test_tensor).item()
    return {'MSE': mse}

# Convert data to tensors before tuning
X_train_tensor = torch.tensor(X_train_sel, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
X_test_tensor = torch.tensor(X_test_sel, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

# Run the tuning
best_model, best_params = tune_bidirectional_lstm(X_train_tensor, y_train_tensor, X_test_tensor, y_test_tensor, sel_indices)
final_metrics = evaluate_model(best_model, X_test_tensor, y_test_tensor, "Best Bidirectional LSTM")
print("\nFinal Model Performance:")
for key, value in final_metrics.items():
    print(f"{key}: {value:.4f}")
# Out:
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.2, batch=32, activation=None
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.2, batch=32, activation=Tanh()
# Early stopping at epoch 46
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.2, batch=32, activation=ReLU()
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.2, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.2, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 28
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.2, batch=64, activation=None
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.2, batch=64, activation=Tanh()
# Early stopping at epoch 46
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.2, batch=64, activation=ReLU()
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.2, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.2, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 37
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.2, batch=128, activation=None
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.2, batch=128, activation=Tanh()
# Early stopping at epoch 45
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.2, batch=128, activation=ReLU()
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.2, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.2, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 38
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.3, batch=32, activation=None
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.3, batch=32, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.3, batch=32, activation=ReLU()
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.3, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.3, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 30
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.3, batch=64, activation=None
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.3, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.3, batch=64, activation=ReLU()
# Early stopping at epoch 22
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.3, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 9
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.3, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 30
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.3, batch=128, activation=None
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.3, batch=128, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.3, batch=128, activation=ReLU()
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.3, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.3, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 29
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.4, batch=32, activation=None
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.4, batch=32, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.4, batch=32, activation=ReLU()
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.4, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.4, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 33
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.4, batch=64, activation=None
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.4, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.4, batch=64, activation=ReLU()
# Early stopping at epoch 11
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.4, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.4, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 34
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.4, batch=128, activation=None
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.4, batch=128, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.4, batch=128, activation=ReLU()
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.4, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=50, layers=1, dropout=0.4, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 27
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.2, batch=32, activation=None
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.2, batch=32, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.2, batch=32, activation=ReLU()
# Early stopping at epoch 32
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.2, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.2, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.2, batch=64, activation=None
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.2, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.2, batch=64, activation=ReLU()
# Early stopping at epoch 30
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.2, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 25
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.2, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.2, batch=128, activation=None
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.2, batch=128, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.2, batch=128, activation=ReLU()
# Early stopping at epoch 42
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.2, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 32
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.2, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 40
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.3, batch=32, activation=None
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.3, batch=32, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.3, batch=32, activation=ReLU()
# Early stopping at epoch 29
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.3, batch=32, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 34
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.3, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 43
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.3, batch=64, activation=None
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.3, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.3, batch=64, activation=ReLU()
# Early stopping at epoch 35
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.3, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 33
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.3, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.3, batch=128, activation=None
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.3, batch=128, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.3, batch=128, activation=ReLU()
# Early stopping at epoch 25
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.3, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 34
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.3, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 45
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.4, batch=32, activation=None
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.4, batch=32, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.4, batch=32, activation=ReLU()
# Early stopping at epoch 38
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.4, batch=32, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 33
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.4, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.4, batch=64, activation=None
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.4, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.4, batch=64, activation=ReLU()
# Early stopping at epoch 29
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.4, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 46
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.4, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.4, batch=128, activation=None
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.4, batch=128, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.4, batch=128, activation=ReLU()
# Early stopping at epoch 37
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.4, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 37
#
# Testing: lr=0.001, hidden=50, layers=2, dropout=0.4, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 42
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.2, batch=32, activation=None
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.2, batch=32, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.2, batch=32, activation=ReLU()
# Early stopping at epoch 40
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.2, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.2, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 50
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.2, batch=64, activation=None
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.2, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.2, batch=64, activation=ReLU()
# Early stopping at epoch 29
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.2, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 36
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.2, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.2, batch=128, activation=None
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.2, batch=128, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.2, batch=128, activation=ReLU()
# Early stopping at epoch 33
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.2, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 35
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.2, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.3, batch=32, activation=None
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.3, batch=32, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.3, batch=32, activation=ReLU()
# Early stopping at epoch 39
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.3, batch=32, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 37
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.3, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 47
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.3, batch=64, activation=None
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.3, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.3, batch=64, activation=ReLU()
# Early stopping at epoch 41
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.3, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 25
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.3, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.3, batch=128, activation=None
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.3, batch=128, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.3, batch=128, activation=ReLU()
# Early stopping at epoch 20
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.3, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 39
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.3, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.4, batch=32, activation=None
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.4, batch=32, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.4, batch=32, activation=ReLU()
# Early stopping at epoch 32
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.4, batch=32, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 33
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.4, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 48
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.4, batch=64, activation=None
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.4, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.4, batch=64, activation=ReLU()
# Early stopping at epoch 32
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.4, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 42
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.4, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.4, batch=128, activation=None
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.4, batch=128, activation=Tanh()
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.4, batch=128, activation=ReLU()
# Early stopping at epoch 33
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.4, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 29
#
# Testing: lr=0.001, hidden=50, layers=3, dropout=0.4, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.2, batch=32, activation=None
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.2, batch=32, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.2, batch=32, activation=ReLU()
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.2, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.2, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 27
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.2, batch=64, activation=None
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.2, batch=64, activation=Tanh()
# Early stopping at epoch 27
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.2, batch=64, activation=ReLU()
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.2, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 10
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.2, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 19
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.2, batch=128, activation=None
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.2, batch=128, activation=Tanh()
# Early stopping at epoch 34
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.2, batch=128, activation=ReLU()
# Early stopping at epoch 8
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.2, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.2, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.3, batch=32, activation=None
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.3, batch=32, activation=Tanh()
# Early stopping at epoch 34
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.3, batch=32, activation=ReLU()
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.3, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.3, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 20
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.3, batch=64, activation=None
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.3, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.3, batch=64, activation=ReLU()
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.3, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.3, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 21
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.3, batch=128, activation=None
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.3, batch=128, activation=Tanh()
# Early stopping at epoch 32
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.3, batch=128, activation=ReLU()
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.3, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.3, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 24
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.4, batch=32, activation=None
# Early stopping at epoch 49
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.4, batch=32, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.4, batch=32, activation=ReLU()
# Early stopping at epoch 13
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.4, batch=32, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 14
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.4, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 21
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.4, batch=64, activation=None
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.4, batch=64, activation=Tanh()
# Early stopping at epoch 42
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.4, batch=64, activation=ReLU()
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.4, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.4, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 32
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.4, batch=128, activation=None
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.4, batch=128, activation=Tanh()
# Early stopping at epoch 48
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.4, batch=128, activation=ReLU()
# Early stopping at epoch 11
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.4, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 11
#
# Testing: lr=0.001, hidden=100, layers=1, dropout=0.4, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 31
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.2, batch=32, activation=None
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.2, batch=32, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.2, batch=32, activation=ReLU()
# Early stopping at epoch 18
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.2, batch=32, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 22
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.2, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.2, batch=64, activation=None
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.2, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.2, batch=64, activation=ReLU()
# Early stopping at epoch 23
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.2, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 22
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.2, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 31
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.2, batch=128, activation=None
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.2, batch=128, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.2, batch=128, activation=ReLU()
# Early stopping at epoch 22
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.2, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 18
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.2, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.3, batch=32, activation=None
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.3, batch=32, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.3, batch=32, activation=ReLU()
# Early stopping at epoch 23
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.3, batch=32, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 41
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.3, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 38
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.3, batch=64, activation=None
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.3, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.3, batch=64, activation=ReLU()
# Early stopping at epoch 31
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.3, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 22
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.3, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 27
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.3, batch=128, activation=None
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.3, batch=128, activation=Tanh()
# Early stopping at epoch 40
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.3, batch=128, activation=ReLU()
# Early stopping at epoch 20
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.3, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 24
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.3, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 35
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.4, batch=32, activation=None
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.4, batch=32, activation=Tanh()
# Early stopping at epoch 49
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.4, batch=32, activation=ReLU()
# Early stopping at epoch 46
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.4, batch=32, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 17
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.4, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.4, batch=64, activation=None
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.4, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.4, batch=64, activation=ReLU()
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.4, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 23
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.4, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 39
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.4, batch=128, activation=None
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.4, batch=128, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.4, batch=128, activation=ReLU()
# Early stopping at epoch 40
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.4, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 24
#
# Testing: lr=0.001, hidden=100, layers=2, dropout=0.4, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 43
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.2, batch=32, activation=None
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.2, batch=32, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.2, batch=32, activation=ReLU()
# Early stopping at epoch 17
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.2, batch=32, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 19
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.2, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.2, batch=64, activation=None
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.2, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.2, batch=64, activation=ReLU()
# Early stopping at epoch 26
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.2, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 50
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.2, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 50
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.2, batch=128, activation=None
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.2, batch=128, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.2, batch=128, activation=ReLU()
# Early stopping at epoch 19
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.2, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 20
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.2, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 42
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.3, batch=32, activation=None
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.3, batch=32, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.3, batch=32, activation=ReLU()
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.3, batch=32, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 18
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.3, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 26
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.3, batch=64, activation=None
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.3, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.3, batch=64, activation=ReLU()
# Early stopping at epoch 21
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.3, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 27
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.3, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 40
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.3, batch=128, activation=None
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.3, batch=128, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.3, batch=128, activation=ReLU()
# Early stopping at epoch 28
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.3, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 24
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.3, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 46
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.4, batch=32, activation=None
# Early stopping at epoch 40
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.4, batch=32, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.4, batch=32, activation=ReLU()
# Early stopping at epoch 25
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.4, batch=32, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 32
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.4, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 50
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.4, batch=64, activation=None
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.4, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.4, batch=64, activation=ReLU()
# Early stopping at epoch 24
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.4, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 21
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.4, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.4, batch=128, activation=None
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.4, batch=128, activation=Tanh()
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.4, batch=128, activation=ReLU()
# Early stopping at epoch 18
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.4, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 25
#
# Testing: lr=0.001, hidden=100, layers=3, dropout=0.4, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 47
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.2, batch=32, activation=None
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.2, batch=32, activation=Tanh()
# Early stopping at epoch 39
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.2, batch=32, activation=ReLU()
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.2, batch=32, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 15
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.2, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.2, batch=64, activation=None
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.2, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.2, batch=64, activation=ReLU()
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.2, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 8
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.2, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 25
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.2, batch=128, activation=None
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.2, batch=128, activation=Tanh()
# Early stopping at epoch 35
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.2, batch=128, activation=ReLU()
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.2, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.2, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 26
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.3, batch=32, activation=None
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.3, batch=32, activation=Tanh()
# Early stopping at epoch 32
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.3, batch=32, activation=ReLU()
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.3, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.3, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.3, batch=64, activation=None
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.3, batch=64, activation=Tanh()
# Early stopping at epoch 44
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.3, batch=64, activation=ReLU()
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.3, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.3, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 26
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.3, batch=128, activation=None
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.3, batch=128, activation=Tanh()
# Early stopping at epoch 37
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.3, batch=128, activation=ReLU()
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.3, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.3, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 17
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.4, batch=32, activation=None
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.4, batch=32, activation=Tanh()
# Early stopping at epoch 33
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.4, batch=32, activation=ReLU()
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.4, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.4, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 22
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.4, batch=64, activation=None
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.4, batch=64, activation=Tanh()
# Early stopping at epoch 44
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.4, batch=64, activation=ReLU()
# Early stopping at epoch 20
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.4, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.4, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 16
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.4, batch=128, activation=None
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.4, batch=128, activation=Tanh()
# Early stopping at epoch 33
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.4, batch=128, activation=ReLU()
# Early stopping at epoch 22
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.4, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 32
#
# Testing: lr=0.001, hidden=150, layers=1, dropout=0.4, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 21
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.2, batch=32, activation=None
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.2, batch=32, activation=Tanh()
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.2, batch=32, activation=ReLU()
# Early stopping at epoch 19
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.2, batch=32, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 17
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.2, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 34
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.2, batch=64, activation=None
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.2, batch=64, activation=Tanh()
# Early stopping at epoch 47
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.2, batch=64, activation=ReLU()
# Early stopping at epoch 18
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.2, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 19
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.2, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 28
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.2, batch=128, activation=None
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.2, batch=128, activation=Tanh()
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.2, batch=128, activation=ReLU()
# Early stopping at epoch 23
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.2, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 17
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.2, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 26
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.3, batch=32, activation=None
# Early stopping at epoch 31
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.3, batch=32, activation=Tanh()
# Early stopping at epoch 45
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.3, batch=32, activation=ReLU()
# Early stopping at epoch 16
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.3, batch=32, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 17
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.3, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 29
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.3, batch=64, activation=None
# Early stopping at epoch 37
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.3, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.3, batch=64, activation=ReLU()
# Early stopping at epoch 16
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.3, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 21
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.3, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 29
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.3, batch=128, activation=None
# Early stopping at epoch 40
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.3, batch=128, activation=Tanh()
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.3, batch=128, activation=ReLU()
# Early stopping at epoch 19
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.3, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 19
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.3, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 24
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.4, batch=32, activation=None
# Early stopping at epoch 32
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.4, batch=32, activation=Tanh()
# Early stopping at epoch 42
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.4, batch=32, activation=ReLU()
# Early stopping at epoch 12
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.4, batch=32, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 17
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.4, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 28
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.4, batch=64, activation=None
# Early stopping at epoch 25
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.4, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.4, batch=64, activation=ReLU()
# Early stopping at epoch 17
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.4, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 15
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.4, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 18
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.4, batch=128, activation=None
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.4, batch=128, activation=Tanh()
# Early stopping at epoch 34
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.4, batch=128, activation=ReLU()
# Early stopping at epoch 20
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.4, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 23
#
# Testing: lr=0.001, hidden=150, layers=2, dropout=0.4, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 44
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.2, batch=32, activation=None
# Early stopping at epoch 47
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.2, batch=32, activation=Tanh()
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.2, batch=32, activation=ReLU()
# Early stopping at epoch 17
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.2, batch=32, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 18
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.2, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 29
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.2, batch=64, activation=None
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.2, batch=64, activation=Tanh()
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.2, batch=64, activation=ReLU()
# Early stopping at epoch 14
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.2, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 23
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.2, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 37
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.2, batch=128, activation=None
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.2, batch=128, activation=Tanh()
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.2, batch=128, activation=ReLU()
# Early stopping at epoch 21
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.2, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 25
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.2, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 23
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.3, batch=32, activation=None
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.3, batch=32, activation=Tanh()
# Early stopping at epoch 48
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.3, batch=32, activation=ReLU()
# Early stopping at epoch 18
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.3, batch=32, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 17
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.3, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 29
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.3, batch=64, activation=None
# Early stopping at epoch 36
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.3, batch=64, activation=Tanh()
# Early stopping at epoch 33
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.3, batch=64, activation=ReLU()
# Early stopping at epoch 11
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.3, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 18
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.3, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 29
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.3, batch=128, activation=None
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.3, batch=128, activation=Tanh()
# Early stopping at epoch 41
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.3, batch=128, activation=ReLU()
# Early stopping at epoch 17
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.3, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 21
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.3, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 36
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.4, batch=32, activation=None
# Early stopping at epoch 43
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.4, batch=32, activation=Tanh()
# Early stopping at epoch 32
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.4, batch=32, activation=ReLU()
# Early stopping at epoch 24
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.4, batch=32, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 22
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.4, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 29
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.4, batch=64, activation=None
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.4, batch=64, activation=Tanh()
# Early stopping at epoch 31
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.4, batch=64, activation=ReLU()
# Early stopping at epoch 16
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.4, batch=64, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 11
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.4, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 32
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.4, batch=128, activation=None
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.4, batch=128, activation=Tanh()
# Early stopping at epoch 29
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.4, batch=128, activation=ReLU()
# Early stopping at epoch 23
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.4, batch=128, activation=LeakyReLU(negative_slope=0.01)
# Early stopping at epoch 21
#
# Testing: lr=0.001, hidden=150, layers=3, dropout=0.4, batch=128, activation=ELU(alpha=1.0)
# Early stopping at epoch 27
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.2, batch=32, activation=None
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.2, batch=32, activation=Tanh()
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.2, batch=32, activation=ReLU()
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.2, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.2, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.2, batch=64, activation=None
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.2, batch=64, activation=Tanh()
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.2, batch=64, activation=ReLU()
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.2, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.2, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.2, batch=128, activation=None
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.2, batch=128, activation=Tanh()
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.2, batch=128, activation=ReLU()
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.2, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.2, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.3, batch=32, activation=None
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.3, batch=32, activation=Tanh()
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.3, batch=32, activation=ReLU()
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.3, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.3, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.3, batch=64, activation=None
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.3, batch=64, activation=Tanh()
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.3, batch=64, activation=ReLU()
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.3, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.3, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.3, batch=128, activation=None
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.3, batch=128, activation=Tanh()
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.3, batch=128, activation=ReLU()
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.3, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.3, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.4, batch=32, activation=None
# Early stopping at epoch 6
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.4, batch=32, activation=Tanh()
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.4, batch=32, activation=ReLU()
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.4, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.4, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.4, batch=64, activation=None
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.4, batch=64, activation=Tanh()
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.4, batch=64, activation=ReLU()
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.4, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.4, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.4, batch=128, activation=None
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.4, batch=128, activation=Tanh()
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.4, batch=128, activation=ReLU()
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.4, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0005, hidden=50, layers=1, dropout=0.4, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.2, batch=32, activation=None
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.2, batch=32, activation=Tanh()
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.2, batch=32, activation=ReLU()
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.2, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.2, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.2, batch=64, activation=None
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.2, batch=64, activation=Tanh()
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.2, batch=64, activation=ReLU()
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.2, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.2, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.2, batch=128, activation=None
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.2, batch=128, activation=Tanh()
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.2, batch=128, activation=ReLU()
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.2, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.2, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.3, batch=32, activation=None
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.3, batch=32, activation=Tanh()
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.3, batch=32, activation=ReLU()
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.3, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.3, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.3, batch=64, activation=None
#
# Testing: lr=0.0005, hidden=50, layers=2, dropout=0.3, batch=64, activation=Tanh()
#
# ...
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.2, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.2, batch=128, activation=None
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.2, batch=128, activation=Tanh()
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.2, batch=128, activation=ReLU()
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.2, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.2, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.3, batch=32, activation=None
# Early stopping at epoch 6
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.3, batch=32, activation=Tanh()
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.3, batch=32, activation=ReLU()
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.3, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.3, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.3, batch=64, activation=None
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.3, batch=64, activation=Tanh()
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.3, batch=64, activation=ReLU()
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.3, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.3, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.3, batch=128, activation=None
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.3, batch=128, activation=Tanh()
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.3, batch=128, activation=ReLU()
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.3, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.3, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.4, batch=32, activation=None
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.4, batch=32, activation=Tanh()
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.4, batch=32, activation=ReLU()
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.4, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.4, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.4, batch=64, activation=None
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.4, batch=64, activation=Tanh()
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.4, batch=64, activation=ReLU()
# Early stopping at epoch 8
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.4, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.4, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.4, batch=128, activation=None
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.4, batch=128, activation=Tanh()
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.4, batch=128, activation=ReLU()
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.4, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=100, layers=3, dropout=0.4, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.2, batch=32, activation=None
# Early stopping at epoch 45
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.2, batch=32, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.2, batch=32, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.2, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.2, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 6
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.2, batch=64, activation=None
# Early stopping at epoch 28
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.2, batch=64, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.2, batch=64, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.2, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.2, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 38
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.2, batch=128, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.2, batch=128, activation=Tanh()
# Early stopping at epoch 40
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.2, batch=128, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.2, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.2, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.3, batch=32, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.3, batch=32, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.3, batch=32, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.3, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.3, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.3, batch=64, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.3, batch=64, activation=Tanh()
# Early stopping at epoch 6
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.3, batch=64, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.3, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.3, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.3, batch=128, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.3, batch=128, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.3, batch=128, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.3, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.3, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.4, batch=32, activation=None
# Early stopping at epoch 12
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.4, batch=32, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.4, batch=32, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.4, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.4, batch=32, activation=ELU(alpha=1.0)
# Early stopping at epoch 11
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.4, batch=64, activation=None
# Early stopping at epoch 36
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.4, batch=64, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.4, batch=64, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.4, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.4, batch=64, activation=ELU(alpha=1.0)
# Early stopping at epoch 6
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.4, batch=128, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.4, batch=128, activation=Tanh()
# Early stopping at epoch 6
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.4, batch=128, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.4, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=1, dropout=0.4, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.2, batch=32, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.2, batch=32, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.2, batch=32, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.2, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.2, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.2, batch=64, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.2, batch=64, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.2, batch=64, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.2, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.2, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.2, batch=128, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.2, batch=128, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.2, batch=128, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.2, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.2, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.3, batch=32, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.3, batch=32, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.3, batch=32, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.3, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.3, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.3, batch=64, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.3, batch=64, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.3, batch=64, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.3, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.3, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.3, batch=128, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.3, batch=128, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.3, batch=128, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.3, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.3, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.4, batch=32, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.4, batch=32, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.4, batch=32, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.4, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.4, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.4, batch=64, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.4, batch=64, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.4, batch=64, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.4, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.4, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.4, batch=128, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.4, batch=128, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.4, batch=128, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.4, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=2, dropout=0.4, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.2, batch=32, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.2, batch=32, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.2, batch=32, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.2, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.2, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.2, batch=64, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.2, batch=64, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.2, batch=64, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.2, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.2, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.2, batch=128, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.2, batch=128, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.2, batch=128, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.2, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.2, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.3, batch=32, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.3, batch=32, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.3, batch=32, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.3, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.3, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.3, batch=64, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.3, batch=64, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.3, batch=64, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.3, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.3, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.3, batch=128, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.3, batch=128, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.3, batch=128, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.3, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.3, batch=128, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.4, batch=32, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.4, batch=32, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.4, batch=32, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.4, batch=32, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.4, batch=32, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.4, batch=64, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.4, batch=64, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.4, batch=64, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.4, batch=64, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.4, batch=64, activation=ELU(alpha=1.0)
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.4, batch=128, activation=None
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.4, batch=128, activation=Tanh()
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.4, batch=128, activation=ReLU()
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.4, batch=128, activation=LeakyReLU(negative_slope=0.01)
#
# Testing: lr=0.0001, hidden=150, layers=3, dropout=0.4, batch=128, activation=ELU(alpha=1.0)
#
# Best Hyperparameters: {'lr': 0.001, 'hidden_size': 150, 'num_layers': 1, 'dropout': 0.2, 'batch_size': 128, 'activation': None}
# Best MSE: 0.0568
#
# Final Model Performance:
# MSE: 0.0568

# %% [markdown]
# # Model Saving

# %%
best_model
# Out:
# BidirectionalLSTM(
#   (lstm1): LSTM(50, 150, batch_first=True, bidirectional=True)
#   (lstm2): LSTM(300, 150, batch_first=True, bidirectional=True)
#   (norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc1): Linear(in_features=300, out_features=150, bias=True)
#   (fc2): Linear(in_features=150, out_features=1, bias=True)
#   (activation): Identity()
# )

# %%
torch.save(best_model.state_dict(), 'best_model.pth')

# %% [markdown]
# # Finalise the Model

# %%
# Define the Bidirectional LSTM model architecture (matching the saved model)
class BidirectionalLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.0, activation=None):
        super(BidirectionalLSTM, self).__init__()
        self.lstm1 = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, bidirectional=True)
        self.lstm2 = nn.LSTM(hidden_size * 2, hidden_size, num_layers, batch_first=True, bidirectional=True)
        self.norm = nn.BatchNorm1d(hidden_size * 2)
        self.dropout = nn.Dropout(dropout)
        self.fc1 = nn.Linear(hidden_size * 2, hidden_size)
        self.fc2 = nn.Linear(hidden_size, output_size)
        self.activation = activation if activation is not None else nn.Identity()

    def forward(self, x):
        out, _ = self.lstm1(x)
        out, _ = self.lstm2(out)
        out = self.norm(out[:, -1, :])  # Use the last time step’s output
        out = self.dropout(out)
        out = self.fc1(out)
        out = self.activation(out)
        out = self.fc2(out)
        return out

# Load the Saved Model
input_size = 50   # Number of features per time step
hidden_size = 150
num_layers = 1
output_size = 1
dropout = 0.2
activation = None  # Identity

best_model = BidirectionalLSTM(input_size, hidden_size, num_layers, output_size, dropout, activation)
best_model.load_state_dict(torch.load('best_model.pth'))
best_model.eval()
# Out:
# BidirectionalLSTM(
#   (lstm1): LSTM(50, 150, batch_first=True, bidirectional=True)
#   (lstm2): LSTM(300, 150, batch_first=True, bidirectional=True)
#   (norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc1): Linear(in_features=300, out_features=150, bias=True)
#   (fc2): Linear(in_features=150, out_features=1, bias=True)
#   (activation): Identity()
# )

# %%
# Model Performance
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
with torch.no_grad():
    predictions = best_model(X_test_tensor).numpy()

mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# Mean Squared Error (MSE): 0.0568
# Root Mean Squared Error (RMSE): 0.2382
# Mean Absolute Error (MAE): 0.2032
# R-squared (R²): 0.0460

# %%
predictions.flatten()
# Out:
# array([0.5914546 , 0.5916501 , 0.5771352 , 0.55852413, 0.558867  ,
#        0.54492205, 0.576754  , 0.60540026], dtype=float32)

# %%
# Plot Predictions vs. Actuals
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual', color='blue')
plt.plot(predictions, label='Predicted', color='red', linestyle='--')
plt.title('Actual vs. Predicted Values')
plt.xlabel('Sample Index')
plt.ylabel('Target Value')
plt.legend()
plt.show()

# %%
# Feature Importance Analysis

# Define a wrapper class to make the PyTorch model compatible with scikit-learn
class PreTrainedModel:
    def __init__(self, model, sequence_length, input_size):
        self.model = model
        self.sequence_length = sequence_length
        self.input_size = input_size

    def fit(self, X, y=None):
        # Since the model is pre-trained, fit does nothing
        return self

    def predict(self, X):
        # X is 2D: (n_samples, sequence_length * input_size)
        n_samples = X.shape[0]
        # Reshape to 3D: (n_samples, sequence_length, input_size) for the LSTM
        X_reshaped = X.reshape(n_samples, self.sequence_length, self.input_size)
        X_tensor = torch.tensor(X_reshaped, dtype=torch.float32)
        with torch.no_grad():
            return self.model(X_tensor).numpy()

# Extract sequence_length from X_test shape
sequence_length = X_test.shape[1]

# Instantiate the wrapper with the pre-trained model
pretrained_estimator = PreTrainedModel(best_model, sequence_length, input_size)

# Reshape X_test to 2D for permutation_importance: (n_samples, sequence_length * input_size)
X_test_flat = X_test.reshape(X_test.shape[0], -1)

# Calculate permutation importance
result = permutation_importance(
    pretrained_estimator,
    X_test_flat,
    y_test,
    scoring='neg_mean_squared_error',
    n_repeats=10,
    random_state=42
)

importances = result.importances_mean

# Aggregate importances for each feature across time steps
aggregated_importances = []
for k in range(input_size):
    importance_k = sum(importances[t * input_size + k] for t in range(sequence_length))
    aggregated_importances.append(importance_k)

# Define feature names with actual names in the order they appear in X_test
feature_names = [
    '^VXN_lag10', '000001.SS_lag42', 'Nonfarm_error', '^N225_lag42', 'Nonfarm_Payrolls_Actual',
    '^VIX_lag10', '^MXX_lag10', 'volume_lag42', 'VXUS_lag1', '^N225_lag1',
    'MACD', 'BZ=F_lag42', 'RSI_14', '^MXX_lag1', '^FTSE',
    'BZ=F_lag10', '^FCHI_lag63', '^BVSP_lag42', 'Personal_Income_Actual', 'BZ=F_lag63',
    'volume_lag1', 'OBV', '^VIX_lag42', '^VXN_lag1', 'volume_lag10',
    '^GDAXI_lag63', 'Personal_Income_Predicted', 'volume', 'Industrial_Production_Predicted', '^GDAXI',
    '^MXX', 'BZ=F_lag1', 'volume_lag63', '^GDAXI_lag10', '^HSI_lag63',
    '^N225_lag10', '^GSPTSE_lag42', 'BTC-USD_lag63', '^HSI_lag42', 'IXN_lag63',
    '^FCHI_lag1', '^VXN_lag42', 'BTC-USD_lag1', '^GSPC_lag10', 'Retail_Sales_Predicted',
    'EMA_50', '^FTSE_lag63', '000001.SS_lag1', '^GSPC_lag63', 'close_lag63'
]

# Create DataFrame with actual feature names
Importance = pd.DataFrame({'Importance': aggregated_importances}, index=feature_names)

# Plot sorted importances with adjustable figure size
fig, ax = plt.subplots(figsize=(10, 12))
Importance.sort_values('Importance', axis=0, ascending=True).plot(kind='barh', color='r', ax=ax)
ax.set_xlabel('Variable Importance')
ax.set_title('Feature Importances')
plt.show()

# %% [markdown]
# # Backtesting Results

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define fixed investment amount for Standard DCA
investment_amount = 1000

# Calculate CPI_change and past returns for the entire dataset
raw_data['CPI_change'] = raw_data['CPI_Actual'].pct_change()
raw_data['return'] = raw_data['close'].pct_change()

# Subset to the last 8 rows
last_8_data = raw_data.iloc[-8:].copy()

# Set 'date' as index if present
if 'date' in last_8_data.columns:
    last_8_data.set_index('date', inplace=True)

# --- Standard DCA ---
last_8_data['investment_std_dca'] = investment_amount
last_8_data['shares_purchased_std_dca'] = last_8_data['investment_std_dca'] / last_8_data['close']
last_8_data['total_shares_std_dca'] = last_8_data['shares_purchased_std_dca'].cumsum()
last_8_data['total_investment_std_dca'] = last_8_data['investment_std_dca'].cumsum()
last_8_data['portfolio_value_std_dca'] = last_8_data['total_shares_std_dca'] * last_8_data['close']

# --- Macro DCA ---
last_8_data['investment_macro_dca'] = np.where(last_8_data['CPI_change'] > 0, 2000, 1000)
last_8_data['shares_purchased_macro_dca'] = last_8_data['investment_macro_dca'] / last_8_data['close']
last_8_data['total_shares_macro_dca'] = last_8_data['shares_purchased_macro_dca'].cumsum()
last_8_data['total_investment_macro_dca'] = last_8_data['investment_macro_dca'].cumsum()
last_8_data['portfolio_value_macro_dca'] = last_8_data['total_shares_macro_dca'] * last_8_data['close']

# --- Prediction-Based DCA ---
# Assumes 'future_log_return' is already assigned to the last 8 rows
last_8_data['investment_pred_dca'] = np.where(last_8_data['future_log_return'] > 0, 2000, 1000)
last_8_data['shares_purchased_pred_dca'] = last_8_data['investment_pred_dca'] / last_8_data['close']
last_8_data['total_shares_pred_dca'] = last_8_data['shares_purchased_pred_dca'].cumsum()
last_8_data['total_investment_pred_dca'] = last_8_data['investment_pred_dca'].cumsum()
last_8_data['portfolio_value_pred_dca'] = last_8_data['total_shares_pred_dca'] * last_8_data['close']

# --- Return-Based DCA ---
last_8_data['investment_return_dca'] = np.where(last_8_data['return'] < 0, 2000, 1000)
last_8_data['shares_purchased_return_dca'] = last_8_data['investment_return_dca'] / last_8_data['close']
last_8_data['total_shares_return_dca'] = last_8_data['shares_purchased_return_dca'].cumsum()
last_8_data['total_investment_return_dca'] = last_8_data['investment_return_dca'].cumsum()
last_8_data['portfolio_value_return_dca'] = last_8_data['total_shares_return_dca'] * last_8_data['close']

# --- Calculate Periodic Returns for Each Strategy ---
for strat in ['std_dca', 'macro_dca', 'pred_dca', 'return_dca']:
    last_8_data[f'returns_{strat}'] = last_8_data[f'portfolio_value_{strat}'].pct_change()

# --- Define Functions for Metrics ---
def total_return(final_value, total_investment):
    return (final_value - total_investment) / total_investment * 100

def annualized_return(total_return, num_periods, periods_per_year=8):
    if num_periods < 1:
        return 0
    return (1 + total_return / 100) ** (periods_per_year / num_periods) - 1

def sharpe_ratio(returns, risk_free_rate=0, periods_per_year=8):
    excess_returns = returns - risk_free_rate / periods_per_year
    return np.mean(excess_returns) / np.std(excess_returns) * np.sqrt(periods_per_year)

def volatility(returns):
    return returns.std()

# --- Calculate Metrics for Each Strategy ---
metrics = {}
for strat in ['std_dca', 'macro_dca', 'pred_dca', 'return_dca']:
    final_value = last_8_data[f'portfolio_value_{strat}'].iloc[-1]
    total_investment = last_8_data[f'total_investment_{strat}'].iloc[-1]
    returns = last_8_data[f'returns_{strat}'].dropna()
    
    metrics[strat] = {
        'Total Return (%)': total_return(final_value, total_investment),
        'Annualized Return (%)': annualized_return(
            total_return(final_value, total_investment), len(last_8_data)
        ) * 100,
        'Sharpe Ratio': sharpe_ratio(returns),
        'Volatility (%)': volatility(returns) * 100
    }

# --- Display Metrics ---
print("Backtest Metrics for Each Strategy (Last 8 Periods):")
for strat, strat_metrics in metrics.items():
    print(f"\n{strat.upper().replace('_', ' ')}")
    for metric, value in strat_metrics.items():
        print(f"{metric}: {value:.2f}")

# --- Plot Portfolio Value Over Time ---
plt.figure(figsize=(12, 6))
for strat in ['std_dca', 'macro_dca', 'pred_dca', 'return_dca']:
    plt.plot(last_8_data.index, last_8_data[f'portfolio_value_{strat}'], label=strat.upper().replace('_', ' '))
plt.title('Portfolio Value Over Time')
plt.xlabel('Date')
plt.ylabel('Portfolio Value ($)')
plt.legend()
plt.show()
plt.close()
# Out:
# Backtest Metrics for Each Strategy (Last 8 Periods):
#
# STD DCA
# Total Return (%): 15.18
# Annualized Return (%): 15.18
# Sharpe Ratio: 3.74
# Volatility (%): 32.81
#
# MACRO DCA
# Total Return (%): 14.67
# Annualized Return (%): 14.67
# Sharpe Ratio: 3.75
# Volatility (%): 40.58
#
# PRED DCA
# Total Return (%): 15.18
# Annualized Return (%): 15.18
# Sharpe Ratio: 3.74
# Volatility (%): 32.81
#
# RETURN DCA
# Total Return (%): 15.12
# Annualized Return (%): 15.12
# Sharpe Ratio: 4.44
# Volatility (%): 30.44

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Assuming raw_data is already loaded
# # Example: raw_data = pd.read_csv('your_data.csv')

# # List of indicators
# indicators = [
#     '^VIX', 'BZ=F', 'XLK', 'BTC-USD', 'IXN', 'VXUS', '^TNX', 'DX-Y.NYB', 
#     '^GSPC', '^VXN', '000001.SS', '^STOXX50E', '^N225', '^GDAXI', 
#     '^GSPTSE', '^MXX', '^FTSE', '^FCHI', '^HSI', '^BSESN', '^AXJO', 
#     '^KS11', '^BVSP'
# ]

# # Check if all required columns are present
# required_cols = ['close'] + indicators
# missing_cols = [col for col in required_cols if col not in raw_data.columns]
# if missing_cols:
#     raise ValueError(f"Missing columns in dataset: {missing_cols}")

# # Calculate correlations with 'close'
# close_corr = raw_data[indicators].corrwith(raw_data['close'])

# # Sort correlations in ascending order
# close_corr_sorted = close_corr.sort_values()

# # Print sorted correlations
# print("Correlations with 'close' (sorted ascending):")
# for indicator, corr in close_corr_sorted.items():
#     print(f"{indicator}: {corr:.4f}")

# # Create a bar plot for visualization
# plt.figure(figsize=(10, 12))
# colors = ['red' if val < 0 else 'blue' for val in close_corr_sorted]
# plt.barh(close_corr_sorted.index, close_corr_sorted, color=colors)
# plt.axvline(0, color='black', linewidth=0.8)
# plt.xlabel('Correlation with Close')
# plt.title('Correlation of Indicators with Close Price')
# plt.grid(axis='x')
# plt.tight_layout()
# plt.show()
# plt.close()

# import pandas as pd
# import numpy as np

# # Define fixed investment amount for Standard DCA
# investment_amount = 1000

# # Calculate CPI_change for the entire dataset
# raw_data['CPI_change'] = raw_data['CPI_Actual'].pct_change()

# # Calculate past returns for the entire dataset
# raw_data['return'] = raw_data['close'].pct_change()

# # Subset to the last 8 rows
# last_8_data = raw_data.iloc[-8:].copy()

# # --- Standard DCA ---
# last_8_data['investment_std_dca'] = investment_amount
# last_8_data['shares_purchased_std_dca'] = last_8_data['investment_std_dca'] / last_8_data['close']
# last_8_data['total_shares_std_dca'] = last_8_data['shares_purchased_std_dca'].cumsum()
# last_8_data['total_investment_std_dca'] = last_8_data['investment_std_dca'].cumsum()
# last_8_data['portfolio_value_std_dca'] = last_8_data['total_shares_std_dca'] * last_8_data['close']

# # --- Macro DCA ---
# # Split investment between close and ^TNX when CPI_change < 0
# condition_macro = last_8_data['CPI_change'] < 0
# last_8_data['investment_macro_dca_close'] = np.where(condition_macro, 500, 1000)
# last_8_data['investment_macro_dca_tnx'] = np.where(condition_macro, 500, 0)

# last_8_data['shares_purchased_macro_dca_close'] = last_8_data['investment_macro_dca_close'] / last_8_data['close']
# last_8_data['shares_purchased_macro_dca_tnx'] = last_8_data['investment_macro_dca_tnx'] / last_8_data['^TNX']

# last_8_data['total_shares_macro_dca_close'] = last_8_data['shares_purchased_macro_dca_close'].cumsum()
# last_8_data['total_shares_macro_dca_tnx'] = last_8_data['shares_purchased_macro_dca_tnx'].cumsum()

# last_8_data['total_investment_macro_dca'] = (
#     last_8_data['investment_macro_dca_close'] + 
#     last_8_data['investment_macro_dca_tnx']
# ).cumsum()

# last_8_data['portfolio_value_macro_dca'] = (
#     last_8_data['total_shares_macro_dca_close'] * last_8_data['close'] + 
#     last_8_data['total_shares_macro_dca_tnx'] * last_8_data['^TNX']
# )

# # --- Prediction-Based DCA ---
# # Split investment between close and ^TNX when future_log_return <= 0
# condition_pred = last_8_data['future_log_return'] <= 0
# last_8_data['investment_pred_dca_close'] = np.where(condition_pred, 500, 1000)
# last_8_data['investment_pred_dca_tnx'] = np.where(condition_pred, 500, 0)

# last_8_data['shares_purchased_pred_dca_close'] = last_8_data['investment_pred_dca_close'] / last_8_data['close']
# last_8_data['shares_purchased_pred_dca_tnx'] = last_8_data['investment_pred_dca_tnx'] / last_8_data['^TNX']

# last_8_data['total_shares_pred_dca_close'] = last_8_data['shares_purchased_pred_dca_close'].cumsum()
# last_8_data['total_shares_pred_dca_tnx'] = last_8_data['shares_purchased_pred_dca_tnx'].cumsum()

# last_8_data['total_investment_pred_dca'] = (
#     last_8_data['investment_pred_dca_close'] + 
#     last_8_data['investment_pred_dca_tnx']
# ).cumsum()

# last_8_data['portfolio_value_pred_dca'] = (
#     last_8_data['total_shares_pred_dca_close'] * last_8_data['close'] + 
#     last_8_data['total_shares_pred_dca_tnx'] * last_8_data['^TNX']
# )

# # --- Return-Based DCA ---
# # Split investment between close and ^TNX when return < 0
# condition_return = last_8_data['return'] < 0
# last_8_data['investment_return_dca_close'] = np.where(condition_return, 500, 1000)
# last_8_data['investment_return_dca_tnx'] = np.where(condition_return, 500, 0)

# last_8_data['shares_purchased_return_dca_close'] = last_8_data['investment_return_dca_close'] / last_8_data['close']
# last_8_data['shares_purchased_return_dca_tnx'] = last_8_data['investment_return_dca_tnx'] / last_8_data['^TNX']

# last_8_data['total_shares_return_dca_close'] = last_8_data['shares_purchased_return_dca_close'].cumsum()
# last_8_data['total_shares_return_dca_tnx'] = last_8_data['shares_purchased_return_dca_tnx'].cumsum()

# last_8_data['total_investment_return_dca'] = (
#     last_8_data['investment_return_dca_close'] + 
#     last_8_data['investment_return_dca_tnx']
# ).cumsum()

# last_8_data['portfolio_value_return_dca'] = (
#     last_8_data['total_shares_return_dca_close'] * last_8_data['close'] + 
#     last_8_data['total_shares_return_dca_tnx'] * last_8_data['^TNX']
# )

# # --- Extract Final Results ---
# final_row = last_8_data.iloc[-1]

# # Standard DCA Metrics
# avg_cost_std_dca = final_row['total_investment_std_dca'] / final_row['total_shares_std_dca']
# gain_std_dca = final_row['portfolio_value_std_dca'] - final_row['total_investment_std_dca']

# # Macro DCA Metrics
# total_shares_macro = final_row['total_shares_macro_dca_close'] + final_row['total_shares_macro_dca_tnx']
# avg_cost_macro_dca = final_row['total_investment_macro_dca'] / total_shares_macro if total_shares_macro != 0 else 0
# gain_macro_dca = final_row['portfolio_value_macro_dca'] - final_row['total_investment_macro_dca']

# # Prediction-Based DCA Metrics
# total_shares_pred = final_row['total_shares_pred_dca_close'] + final_row['total_shares_pred_dca_tnx']
# avg_cost_pred_dca = final_row['total_investment_pred_dca'] / total_shares_pred if total_shares_pred != 0 else 0
# gain_pred_dca = final_row['portfolio_value_pred_dca'] - final_row['total_investment_pred_dca']

# # Return-Based DCA Metrics
# total_shares_return = final_row['total_shares_return_dca_close'] + final_row['total_shares_return_dca_tnx']
# avg_cost_return_dca = final_row['total_investment_return_dca'] / total_shares_return if total_shares_return != 0 else 0
# gain_return_dca = final_row['portfolio_value_return_dca'] - final_row['total_investment_return_dca']

# # Display Results
# print("Standard DCA (Last 8 Periods):")
# print(f"Average Cost per Share: ${avg_cost_std_dca:.2f}")
# print(f"Unrealized Gain: ${gain_std_dca:.2f}")

# print("\nMacro DCA (Last 8 Periods):")
# print(f"Average Cost per Share: ${avg_cost_macro_dca:.2f}")
# print(f"Unrealized Gain: ${gain_macro_dca:.2f}")

# print("\nPrediction-Based DCA (Last 8 Periods):")
# print(f"Average Cost per Share: ${avg_cost_pred_dca:.2f}")
# print(f"Unrealized Gain: ${gain_pred_dca:.2f}")

# print("\nReturn-Based DCA (Last 8 Periods):")
# print(f"Average Cost per Share: ${avg_cost_return_dca:.2f}")
# print(f"Unrealized Gain: ${gain_return_dca:.2f}")

# %%
# import pandas as pd
# import numpy as np
# import torch
# import torch.nn as nn
# import torch.optim as optim
# from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# from sklearn.model_selection import TimeSeriesSplit
# from sklearn.feature_selection import RFECV
# from sklearn.ensemble import RandomForestRegressor
# from torch.utils.data import DataLoader, TensorDataset
# import matplotlib.pyplot as plt
# import itertools
# from scipy.stats import norm

# # Step 1: Load Data
# def load_stock_data(file_path, start_date, end_date):
#     """Load stock data from SQLite database using StockFeaturePipeline."""
#     pipeline = StockFeaturePipeline(file_path)
#     data = pipeline.run_pipeline(start_date, end_date)
#     return data

# # Step 2: Handle Missing Values
# def handle_missing_values(df):
#     """Remove rows with missing target and fill NaNs in numerical columns with means."""
#     df = df.dropna(subset=['Future_Log_Returns'])  # Drop rows where target is NaN
#     numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.drop('Future_Log_Returns', errors='ignore')
#     for col in numerical_cols:
#         df[col] = df[col].fillna(df[col].mean())
#     return df

# # Step 3: Detect and Handle Outliers
# def z_score_mark_outliers(df, threshold=3, handle_outliers=True):
#     """Detect and cap outliers using z-scores."""
#     df = df.copy()
#     numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
    
#     if not numerical_cols.size:
#         print("No numerical columns found.")
#         return df
    
#     total_outliers = 0
#     for col in numerical_cols:
#         mean = df[col].mean()
#         std = df[col].std()
#         if std == 0:
#             continue
#         z_scores = np.abs((df[col] - mean) / std)
#         col_outliers = z_scores > threshold
#         total_outliers += col_outliers.sum()
#         if handle_outliers:
#             lower_bound = mean - threshold * std
#             upper_bound = mean + threshold * std
#             df[col] = df[col].clip(lower=lower_bound, upper=upper_bound)
    
#     prob = 100 * 2 * norm.sf(threshold)
#     print(f"z-score threshold {threshold}: {prob:.2f}% probability, {total_outliers} outliers handled.")
#     return df

# # Step 4: Apply Log Transformation
# def log_transform_df(df):
#     """Apply log transformation to numerical columns, handling non-positive values."""
#     df = df.copy()
#     numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
    
#     if not numerical_cols.size:
#         print("No numerical columns found.")
#         return df
    
#     for col in numerical_cols:
#         min_value = df[col].min()
#         constant = abs(min_value) + 1 if min_value <= 0 else 1
#         df[col] = np.log(df[col] + constant)
#     return df

# # Step 5: Scale Data
# def min_max_scaler_all_numerical(df, feature_range=(0, 1)):
#     """Scale all numerical columns using Min-Max scaling."""
#     df = df.copy()
#     numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
    
#     if not numerical_cols.size:
#         print("No numerical columns found.")
#         return df
    
#     for col in numerical_cols:
#         if df[col].isna().all() or df[col].nunique() <= 1:
#             print(f"Skipping {col}: NaN or constant.")
#             continue
#         col_min, col_max = df[col].min(), df[col].max()
#         if col_max == col_min:
#             continue
#         df[col] = (df[col] - col_min) / (col_max - col_min) * (feature_range[1] - feature_range[0]) + feature_range[0]
#     return df

# # Step 6: Prepare Sequences
# def prepare_sequences(df, seq_len=10, test_size=0.2):
#     """Convert DataFrame into sequences for time series modeling."""
#     for col in df.columns:
#         if pd.api.types.is_period_dtype(df[col]):
#             df[col] = df[col].apply(lambda x: x.to_timestamp().toordinal() if pd.notnull(x) else np.nan)
    
#     numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns.drop('Future_Log_Returns', errors='ignore')
#     for col in numerical_cols:
#         q1, q3 = df[col].quantile([0.25, 0.75])
#         iqr = q3 - q1
#         df[col] = df[col].clip(q1 - 1.5 * iqr, q3 + 1.5 * iqr)
#     df[numerical_cols] = df[numerical_cols].fillna(method='ffill').fillna(0)
    
#     X_seq, y_seq = [], []
#     for i in range(seq_len, len(df)):
#         X_seq.append(df.iloc[i-seq_len:i][numerical_cols].values)
#         y_seq.append(df.iloc[i]['Future_Log_Returns'])
#     X_seq, y_seq = np.array(X_seq, dtype=float), np.array(y_seq, dtype=float)
    
#     if not np.all(np.isfinite(X_seq)) or not np.all(np.isfinite(y_seq)):
#         raise ValueError("Data contains NaN or infinite values")
    
#     train_size = int((1 - test_size) * len(X_seq))
#     X_train, y_train = X_seq[:train_size], y_seq[:train_size]
#     X_test, y_test = X_seq[train_size:], y_seq[train_size:]
#     return X_train, y_train, X_test, y_test, numerical_cols

# # Step 7: Select Features
# def select_features(X_train, y_train, X_test, numerical_cols, n_features=50):
#     """Select top features using RFECV."""
#     X_train_last = X_train[:, -1, :]
#     estimator = RandomForestRegressor(n_estimators=100, random_state=42)
#     rfecv = RFECV(estimator, step=1, cv=TimeSeriesSplit(n_splits=5), scoring='neg_mean_squared_error')
#     rfecv.fit(X_train_last, y_train)
    
#     selected_mask = rfecv.support_
#     selected_features = numerical_cols[selected_mask]
#     importances = rfecv.estimator_.feature_importances_
#     feature_df = pd.DataFrame({'feature': selected_features, 'importance': importances}).sort_values('importance', ascending=False)
#     top_features = feature_df.head(n_features)['feature'].tolist()
#     selected_indices = [list(numerical_cols).index(f) for f in top_features]
    
#     print(f"Selected {len(selected_indices)} features:")
#     print(feature_df.head(n_features))
#     return X_train[:, :, selected_indices], X_test[:, :, selected_indices], selected_indices

# # Step 8: Define Models
# class VanillaLSTM(nn.Module):
#     def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.3):
#         super().__init__()
#         self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
#         self.fc = nn.Linear(hidden_size, output_size)
#         self.dropout = nn.Dropout(dropout)
    
#     def forward(self, x):
#         _, (h_n, _) = self.lstm(x)
#         x = self.dropout(h_n[-1])
#         return self.fc(x)

# class BidirectionalLSTM(nn.Module):
#     def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.3):
#         super().__init__()
#         self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, bidirectional=True)
#         self.fc = nn.Linear(hidden_size * 2, output_size)
#         self.dropout = nn.Dropout(dropout)
    
#     def forward(self, x):
#         _, (h_n, _) = self.lstm(x)
#         h_n = torch.cat((h_n[-2], h_n[-1]), dim=1)
#         x = self.dropout(h_n)
#         return self.fc(x)

# class CNNLSTM(nn.Module):
#     def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.3):
#         super().__init__()
#         self.conv1 = nn.Conv1d(input_size, 64, kernel_size=3, padding=1)
#         self.conv2 = nn.Conv1d(64, 128, kernel_size=3, padding=1)
#         self.lstm = nn.LSTM(128, hidden_size, num_layers, batch_first=True)
#         self.fc = nn.Linear(hidden_size, output_size)
#         self.dropout = nn.Dropout(dropout)
    
#     def forward(self, x):
#         x = x.permute(0, 2, 1)
#         x = torch.relu(self.conv1(x))
#         x = self.dropout(x)
#         x = torch.relu(self.conv2(x))
#         x = self.dropout(x)
#         x = x.permute(0, 2, 1)
#         _, (h_n, _) = self.lstm(x)
#         x = self.dropout(h_n[-1])
#         return self.fc(x)

# # Step 9: Train Model
# def train_model(model, train_loader, X_test_tensor, y_test, epochs=50, patience=5, lr=0.0005):
#     """Train a PyTorch model with early stopping."""
#     criterion = nn.MSELoss()
#     optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)
#     best_loss = float('inf')
#     trigger = 0
    
#     for epoch in range(epochs):
#         model.train()
#         running_loss = 0.0
#         for X_batch, y_batch in train_loader:
#             optimizer.zero_grad()
#             outputs = model(X_batch)
#             loss = criterion(outputs, y_batch)
#             loss.backward()
#             optimizer.step()
#             running_loss += loss.item()
#         avg_loss = running_loss / len(train_loader)
#         print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}")
        
#         model.eval()
#         with torch.no_grad():
#             y_pred = model(X_test_tensor).numpy().flatten()
#             val_loss = mean_squared_error(y_test, y_pred)
#             if val_loss < best_loss:
#                 best_loss = val_loss
#                 trigger = 0
#             else:
#                 trigger += 1
#                 if trigger >= patience:
#                     print("Early stopping triggered")
#                     break
#     return model

# # Step 10: Evaluate Model
# def evaluate_model(model, X_test_tensor, y_test, model_name):
#     """Evaluate model performance and save residual plot."""
#     model.eval()
#     with torch.no_grad():
#         y_pred = model(X_test_tensor).numpy().flatten()
    
#     mse = mean_squared_error(y_test, y_pred)
#     rmse = np.sqrt(mse)
#     mae = mean_absolute_error(y_test, y_pred)
#     r2 = r2_score(y_test, y_pred)
    
#     print(f"\n{model_name} Performance:")
#     print(f"MSE: {mse:.4f}, RMSE: {rmse:.4f}, MAE: {mae:.4f}, R²: {r2:.4f}")
    
#     residuals = y_test - y_pred
#     plt.figure(figsize=(10, 6))
#     plt.plot(residuals, label='Residuals')
#     plt.title(f"{model_name} Residuals")
#     plt.xlabel("Test Sample Index")
#     plt.ylabel("Residual Value")
#     plt.legend()
#     plt.grid(True)
#     plt.savefig(f'{model_name.lower().replace(" ", "_")}_residuals.png')
#     plt.close()
    
#     return {'MSE': mse, 'RMSE': rmse, 'MAE': mae, 'R2': r2}

# # Step 11: Tune Bidirectional LSTM
# def tune_bidirectional_lstm(X_train_tensor, y_train_tensor, X_test_tensor, y_test, sel_indices):
#     """Perform grid search to tune Bidirectional LSTM hyperparameters."""
#     learning_rates = [0.001, 0.0005, 0.0001]
#     hidden_sizes = [50, 100, 150]
#     num_layers_list = [1, 2, 3]
#     dropout_rates = [0.2, 0.3, 0.4]
#     batch_sizes = [32, 64, 128]
    
#     best_r2 = -float('inf')
#     best_params = {}
#     best_model = None
    
#     param_combinations = list(itertools.product(learning_rates, hidden_sizes, num_layers_list, dropout_rates, batch_sizes))
    
#     for lr, hidden_size, num_layers, dropout, batch_size in param_combinations:
#         print(f"\nTesting: lr={lr}, hidden={hidden_size}, layers={num_layers}, dropout={dropout}, batch={batch_size}")
#         train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
#         train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
        
#         model = BidirectionalLSTM(input_size=len(sel_indices), hidden_size=hidden_size, num_layers=num_layers, output_size=1, dropout=dropout)
#         trained_model = train_model(model, train_loader, X_test_tensor, y_test, epochs=50, patience=5, lr=lr)
#         metrics = evaluate_model(trained_model, X_test_tensor, y_test, f"BiLSTM (lr={lr}, hidden={hidden_size})")
        
#         if metrics['R2'] > best_r2:
#             best_r2 = metrics['R2']
#             best_params = {'lr': lr, 'hidden_size': hidden_size, 'num_layers': num_layers, 'dropout': dropout, 'batch_size': batch_size}
#             best_model = trained_model
    
#     print("\nBest Hyperparameters:", best_params)
#     print(f"Best R²: {best_r2:.4f}")
#     return best_model, best_params

# # Step 12: Main Execution Pipeline
# def main():
#     """Execute the full stock prediction pipeline."""
#     # Load and preprocess data
#     file_path = '/Users/kevinleungch421/Documents/GitHub/Database/DataBase/stock_price.sqlite'
#     raw_data = load_stock_data(file_path, '2017-01-01', '2021-01-01')
#     clean_data = handle_missing_values(raw_data)
#     outlier_data = z_score_mark_outliers(clean_data)
#     transformed_data = log_transform_df(outlier_data)
#     scaled_df = min_max_scaler_all_numerical(transformed_data)
    
#     # Prepare sequences and features
#     X_train, y_train, X_test, y_test, numerical_cols = prepare_sequences(scaled_df)
#     X_train_sel, X_test_sel, sel_indices = select_features(X_train, y_train, X_test, numerical_cols)
    
#     # Convert to tensors
#     X_train_tensor = torch.tensor(X_train_sel, dtype=torch.float32)
#     y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
#     X_test_tensor = torch.tensor(X_test_sel, dtype=torch.float32)
#     train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
#     train_loader = DataLoader(train_dataset, batch_size=64, shuffle=False)
    
#     # Compare models
#     model_configs = [
#         ('Vanilla LSTM', VanillaLSTM(len(sel_indices), 100, 2, 1)),
#         ('Bidirectional LSTM', BidirectionalLSTM(len(sel_indices), 100, 2, 1)),
#         ('CNN-LSTM', CNNLSTM(len(sel_indices), 100, 2, 1))
#     ]
    
#     results = {}
#     for name, model in model_configs:
#         print(f"\nTraining {name}...")
#         trained_model = train_model(model, train_loader, X_test_tensor, y_test)
#         results[name] = evaluate_model(trained_model, X_test_tensor, y_test, name)
    
#     print("\nModel Comparison Summary:")
#     for name, metrics in results.items():
#         print(f"{name}: MSE={metrics['MSE']:.4f}, RMSE={metrics['RMSE']:.4f}, MAE={metrics['MAE']:.4f}, R²={metrics['R2']:.4f}")
    
#     # Optimize Bidirectional LSTM
#     best_model, best_params = tune_bidirectional_lstm(X_train_tensor, y_train_tensor, X_test_tensor, y_test, sel_indices)
#     final_metrics = evaluate_model(best_model, X_test_tensor, y_test, "Best Bidirectional LSTM")
#     print("\nFinal Model Performance:")
#     for key, value in final_metrics.items():
#         print(f"{key}: {value:.4f}")

# if __name__ == "__main__":
#     main()

# %%
# import torch.nn as nn

# class BidirectionalLSTM(nn.Module):
#     def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.0, activation=None):
#         super(BidirectionalLSTM, self).__init__()
#         self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, bidirectional=True, dropout=dropout if num_layers > 1 else 0)
#         self.dropout = nn.Dropout(dropout)
#         self.fc = nn.Linear(hidden_size * 2, output_size)
#         # Set activation function (default to None for linear output)
#         self.activation = activation if activation is not None else nn.Identity()

#     def forward(self, x):
#         out, _ = self.lstm(x)
#         out = self.dropout(out[:, -1, :])
#         out = self.fc(out)
#         out = self.activation(out)  # Apply the activation function
#         return out

# from torch.utils.data import DataLoader, TensorDataset
# import itertools

# def tune_bidirectional_lstm(X_train_tensor, y_train_tensor, X_test_tensor, y_test, sel_indices):
#     """Perform grid search to tune Bidirectional LSTM hyperparameters, including activation functions."""
#     learning_rates = [0.001, 0.0005, 0.0001]
#     hidden_sizes = [50, 100, 150]
#     num_layers_list = [1, 2, 3]
#     dropout_rates = [0.2, 0.3, 0.4]
#     batch_sizes = [32, 64, 128]
#     activations = [None, nn.Tanh(), nn.ReLU()]  # List of activation functions to test

#     best_r2 = -float('inf')
#     best_params = {}
#     best_model = None

#     # Include activations in the parameter combinations
#     param_combinations = list(itertools.product(learning_rates, hidden_sizes, num_layers_list, dropout_rates, batch_sizes, activations))

#     for lr, hidden_size, num_layers, dropout, batch_size, activation in param_combinations:
#         print(f"\nTesting: lr={lr}, hidden={hidden_size}, layers={num_layers}, dropout={dropout}, batch={batch_size}, activation={activation}")
#         train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
#         train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

#         # Initialize the model with the activation function
#         model = BidirectionalLSTM(input_size=len(sel_indices), hidden_size=hidden_size, num_layers=num_layers, output_size=1, dropout=dropout, activation=activation)
#         trained_model = train_model(model, train_loader, X_test_tensor, y_test, epochs=50, patience=5, lr=lr)
#         metrics = evaluate_model(trained_model, X_test_tensor, y_test, f"BiLSTM (lr={lr}, hidden={hidden_size}, activation={activation})")

#         if metrics['R2'] > best_r2:
#             best_r2 = metrics['R2']
#             best_params = {
#                 'lr': lr,
#                 'hidden_size': hidden_size,
#                 'num_layers': num_layers,
#                 'dropout': dropout,
#                 'batch_size': batch_size,
#                 'activation': activation
#             }
#             best_model = trained_model

#     print("\nBest Hyperparameters:", best_params)
#     print(f"Best R²: {best_r2:.4f}")
#     return best_model, best_params

# # Run the tuning function
# best_model, best_params = tune_bidirectional_lstm(X_train_tensor, y_train_tensor, X_test_tensor, y_test, sel_indices)
# final_metrics = evaluate_model(best_model, X_test_tensor, y_test, "Best Bidirectional LSTM")
# print("\nFinal Model Performance:")
# for key, value in final_metrics.items():
#     print(f"{key}: {value:.4f}")
